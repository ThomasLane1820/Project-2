# %% [markdown]
# ## Imports

# %%
# Import packages
import os, time, json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tmdbsimple as tmdb 
import pandas as pd
from tqdm.notebook import tqdm_notebook

# %%
import glob
# Use glob to get all filepaths that match the pattern (*=wildcard)
tmdb_files = sorted(glob.glob("Data/final_tmdb_data*.csv.gz"))
tmdb_files
# Out:
# ['Data\\final_tmdb_data_2001.csv.gz',
#  'Data\\final_tmdb_data_2002.csv.gz',
#  'Data\\final_tmdb_data_2010.csv.gz']

# %%
# Use read_csv in a list comprehension and combine with concat to load all files
df = pd.concat([pd.read_csv(f) for f in tmdb_files] )
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
#
# ...

# %% [markdown]
# ## Visualizations

# %%
no_finance_info = (df['budget']  == 0) & (df['revenue'] == 0)
no_finance_info.value_counts()
# Out:
# True     4913
# False    1812
# dtype: int64

# %% [markdown]
# There are 1812 movies that have either budget information or revenue information

# %%
no_fin_filtered_df = df[~no_finance_info]
no_fin_filtered_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 5  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
# 6  tt0119004    0.0  /7xrlSPGDO4CDT6IHTctDlkYxTzw.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 4  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 5   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
# 6         0.0                      [{'id': 18, 'name': 'Drama'}]      NaN
#
# ...

# %% [markdown]
# Movies in each of the certification categories (G/PG/PG-13/R).

# %%
# Countplot with many categories
ax = sns.countplot(data = no_fin_filtered_df, x = 'certification')

# %% [markdown]
# The average revenue per certification category.

# %%
# Making a seaborn barplot as a starting point
ax = sns.barplot( no_fin_filtered_df, x = 'certification', y = 'revenue')

# %% [markdown]
# The average budget per certification category.

# %%
# Making a seaborn barplot as a starting point
ax = sns.barplot( no_fin_filtered_df, x = 'certification', y = 'budget')
